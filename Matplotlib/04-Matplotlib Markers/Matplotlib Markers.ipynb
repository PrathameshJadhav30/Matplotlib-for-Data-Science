# %% [markdown]
# Mark each point with a circle:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3,8,1,7,10,4])

plt.plot(ypoints,marker = 'o')
plt.show()

# %% [markdown]
# Mark each point with a star:

# %%
plt.plot(ypoints , marker ='*')

# %% [markdown]
# Marker	Description
# 'o'	Circle
# '*'	Star
# '.'	Point
# ','	Pixel
# 'x'	X
# 'X'	X (filled)
# '+'	Plus
# 'P'	Plus (filled)
# 's'	Square
# 'D'	Diamond
# 'd'	Diamond (thin)
# 'p'	Pentagon
# 'H'	Hexagon
# 'h'	Hexagon
# 'v'	Triangle Down
# '^'	Triangle Up
# '<'	Triangle Left
# '>'	Triangle Right
# '1'	Tri Down
# '2'	Tri Up
# '3'	Tri Left
# '4'	Tri Right
# '|'	Vline
# '_'	Hline

# %% [markdown]
# Mark each point with a circle:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3,8,4,1,10,7])

plt.plot(ypoints, 'o:r')
plt.show()

# %% [markdown]
# Line Syntax	Description
# '-'	Solid line
# ':'	Dotted line
# '--'	Dashed line
# '-.'	Dashed/dotted line

# %% [markdown]
# Color Syntax	Description
# 'r'	Red
# 'g'	Green
# 'b'	Blue
# 'c'	Cyan
# 'm'	Magenta
# 'y'	Yellow
# 'k'	Black
# 'w'	White

# %% [markdown]
# Set the size of the markers to 20:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3,6,4,8,9,10])

plt.plot(ypoints, marker ='o', ms=20)
plt.show()

# %% [markdown]
# Set the EDGE color to red:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3,6,8,9,3,10,15,12])
plt.plot(ypoints,marker ='o',ms=20, mec ='r')
plt.show()

# %% [markdown]
# Set the FACE color to red:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3,6,8,3,5,19,10])
plt.plot(ypoints,marker ='o',ms =20,mfc ='r')
plt.show()

# %% [markdown]
# Set the color of both the edge and the face to red:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([4,6,8,12,3,5,9,20])
plt.plot(ypoints,marker ='o',ms = 20, mec ='r', mfc='r')
plt.show()
