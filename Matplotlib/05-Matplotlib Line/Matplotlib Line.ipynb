# %% [markdown]
# Use a dotted line:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([6,3,8,4,16,27,1,9])
plt.plot(ypoints, linestyle = 'dotted')
plt.show()

# %% [markdown]
# Use a dashed line:

# %%
plt.plot(ypoints , linestyle ='dashed')

# %% [markdown]
# Shorter Syntax
# The line style can be written in a shorter syntax:
#
# linestyle can be written as ls.
#
# dotted can be written as :.
#
# dashed can be written as --.

# %% [markdown]
# Shorter syntax:

# %%
plt.plot(ypoints,ls =':')

# %% [markdown]
# Style	Or
# 'solid' (default)	'-'
# 'dotted'	':'
# 'dashed'	'--'
# 'dashdot'	'-.'
# 'None'	'' or ' '

# %% [markdown]
# Set the line color to red:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3,8,5,1,10])
plt.plot(ypoints,color ='r')
plt.show()

# %% [markdown]
# Plot with a beautiful green line:

# %%
plt.plot(ypoints, c = '#4CAF50')

# %% [markdown]
# Plot with the color named "hotpink":

# %%
plt.plot(ypoints, c = 'hotpink')

# %% [markdown]
# Plot with a 20.5pt wide line:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3,5,8,10])

plt.plot(ypoints,linewidth = '20.5')
plt.show()

# %% [markdown]
# Draw two lines by specifying a plt.plot() function for each line:

# %%
import matplotlib.pyplot as plt
import numpy as np

y1 = np.array([3,8,1,10])
y2 = np.array([6,2,7,11])

plt.plot(y1)
plt.plot(y2)

plt.show()

# %% [markdown]
# Draw two lines by specifiyng the x- and y-point values for both lines:

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([0,1,2,4,3])
y1 = np.array([3,5,8,19,6])
x2 = np.array([0,1,2,3,9])
y2 = np.array([6,2,7,11,20])

plt.plot(x1,y1,x2,y2)
plt.show()
